# %% [markdown]
# # Kings of War Custom Unit Cost Estimator

# %% [markdown]
# ## Project Goal
# This project aims to estimate the cost of a custom unit for the Kings of War miniature game.

# %% [markdown]
# ## Methodology
# The goal will be achieved by the following steps:
# 1. Create a database with all Kings of War units in a given army and their associated point cost. Include the following information:
#     - all basic stats (melee, ranged, etc.)
#     - qualitative matrix of:
#         - unit size
#         - special abilities
#         - army name
#         - army alignment (evil, neutral, good)
# 2. Separate database into two groups:
#     - training data
#     - testing data
# 3. Develop or implement (using scipy) multiple linear regression model on training data
# 4. Test the model using testing data to estimate accuracy
# 5. Evaluate performance and decide if further development is needed
# 6. Create function that returns cost for a given custom unit input

# %% [markdown]
# ## Step 1: Create Database
# Ideally, the information needed can be found online; however, the search has come up empty on publically available informaiton so the data will be created and stored in a .csv.  In order to reduce the scope, the Undead Armies will be the initial focus and will move on to other armies once complete.  The list of headers for the data table can be seen below as well as the list of KoW armies.

# %%
headers = ['Army Name', 'Army Alignment',
           'Unit Name', 'Unit Type', 'Unit Size',
           'Sp', 'Me', 'Ra', 'De', 'Att', 'Ne', 'Pts',
          'Special']
armies = ['Undead Armies']

# %% [markdown]
# Now that the databases are created, the data can be imported into a pandas dataframe.

# %%
# create a list of df from the army list above
# use pd.concat method to create final df per pandas documentation
import pandas as pd

units_list = []
for army in armies:
    units_list.append(pd.read_csv(army + '.csv'))

units = pd.concat(units_list)
units
# Out:
#         Army Name  Army Allegiance                      Unit Name  \
# 0   Undead Armies             Evil              Skeleton Warriors
# 1   Undead Armies             Evil              Skeleton Warriors
# 2   Undead Armies             Evil              Skeleton Warriors
# 3   Undead Armies             Evil               Skeleton Archers
# 4   Undead Armies             Evil               Skeleton Archers
# 5   Undead Armies             Evil               Skeleton Archers
# 6   Undead Armies             Evil              Skeleton Spearmen
# 7   Undead Armies             Evil              Skeleton Spearmen
# 8   Undead Armies             Evil              Skeleton Spearmen
# 9   Undead Armies             Evil                         Ghouls
# 10  Undead Armies             Evil                         Ghouls
# 11  Undead Armies             Evil                         Ghouls
# 12  Undead Armies             Evil           Soul Reaver Infantry
# 13  Undead Armies             Evil           Soul Reaver Infantry
# 14  Undead Armies             Evil            Soul Reaver Cavalry
# 15  Undead Armies             Evil            Soul Reaver Cavalry
# 16  Undead Armies             Evil                      Revenants
# 17  Undead Armies             Evil                      Revenants
# 18  Undead Armies             Evil                      Revenants
# 19  Undead Armies             Evil               Revenant Cavalry
# 20  Undead Armies             Evil               Revenant Cavalry
# 21  Undead Armies             Evil                        Wraiths
# 22  Undead Armies             Evil                        Wraiths
# 23  Undead Armies             Evil                        Zombies
# 24  Undead Armies             Evil                        Zombies
# 25  Undead Armies             Evil                        Zombies
# 26  Undead Armies             Evil                        Mummies
# 27  Undead Armies             Evil                        Mummies
# 28  Undead Armies             Evil                  Zombie Trolls
# 29  Undead Armies             Evil                  Zombie Trolls
# 30  Undead Armies             Evil                     Werewolves
# 31  Undead Armies             Evil                     Werewolves
# 32  Undead Armies             Evil                  Revenant King
# 33  Undead Armies             Evil   Revenant King on Undead Wyrm
# 34  Undead Armies             Evil                         Wights
# 35  Undead Armies             Evil                         Wights
# 36  Undead Armies             Evil    Undead Army Standard Bearer
# 37  Undead Armies             Evil              Balefire Catapult
# 38  Undead Armies             Evil                 Cursed Pharaoh
# 39  Undead Armies             Evil      Vampire on Undead Pegasus
# 40  Undead Armies             Evil                   Vampire Lord
# 41  Undead Armies             Evil       Vampire on Undead Dragon
# 42  Undead Armies             Evil                        Lykanis
# 43  Undead Armies             Evil                 Lady Ilona [1]
# 44  Undead Armies             Evil                     Liche King
# 45  Undead Armies             Evil                    Necromancer
# 46  Undead Armies             Evil      Mhorgoth the Faceless [1]
#
#           Unit Type  Unit Size   Sp   Me   Ra   De   Att      Ne   Pts  \
# 0          Infantry      Troop    5    5    0    4    10    0/12    65
# 1          Infantry   Regiment    5    5    0    4    12    0/16    90
# 2          Infantry      Horde    5    5    0    4    25    0/23   150
# 3          Infantry      Troop    5    6    5    3     8    0/12    75
# 4          Infantry   Regiment    5    6    5    3    10    0/16   100
# 5          Infantry      Horde    5    6    5    3    20    0/23   165
# 6           Infanty      Troop    5    5    0    4    10    0/12    75
# 7           Infanty   Regiment    5    5    0    4    15    0/16   105
# 8           Infanty      Horde    5    5    0    4    30    0/23   175
# 9          Infantry      Troop    6    4    0    3    10    8/10    65
# 10         Infantry   Regiment    6    4    0    3    12   12/14    90
# 11         Infantry      Horde    6    4    0    3    25   19/21   150
# 12         Infantry      Troop    6    3    0    5    20   11/13   180
# 13         Infantry   Regiment    6    3    0    5    25   15/17   260
# 14          Cavalry      Troop    8    3    0    6    10   12/14   195
# 15          Cavalry      Troop    8    3    0    6    20   15/17   300
# 16         Infantry      Troop    5    4    0    5    10    0/13    85
# 17         Infantry   Regiment    5    4    0    5    12    0/17   120
# 18         Infantry      Horde    5    4    0    5    25    0/24   200
# 19          Cavalry      Troop    8    4    0    5     8    0/14   110
# 20          Cavalry   Regiment    8    4    0    5    16    0/17   170
# 21         Infantry      Troop   10    4    0    6    10    0/12   140
# 22         Infantry   Regiment   10    4    0    6    12    0/16   200
# 23         Infantry   Regiment    5    5    0    3    15    0/15    80
# 24         Infantry      Horde    5    5    0    3    30    0/22   130
# 25         Infantry     Legion    5    5    0    3    40    0/28   190
# 26         Infantry      Troop    5    4    0    5    10    0/14   120
# 27         Infantry   Regiment    5    4    0    5    12    0/18   170
# 28   Large Infantry   Regiment    6    4    0    4     9    0/15   115
# 29   Large Infantry      Horde    6    4    0    4    18    0/18   175
# 30   Large Infantry   Regiment    9    3    0    5     9   12/14   160
# 31   Large Infantry      Horde    9    3    0    5    18   15/17   245
# 32        Hero(Inf)          1    5    4    0    5     5   14/16   120
# 33        Hero(Mon)          1    7    4    0    5     9   18/20   190
# 34   Large Infantry   Regiment    6    4    0    5     9    0/14   155
# 35   Large Infantry      Horde    6    4    0    5    18    0/17   235
# 36        Hero(Inf)          1    5    5    0    4     1    -/13    50
# 37       War Engine          1    5    0    5    4     1    0/11   100
# 38        Hero(Inf)          1    5    3    0    6     5   15/17   145
# 39    Hero(Lrg Cav)          1   10    3    0    5     8   14/16   245
# 40        Hero(Inf)          1    7    3    0    6     8   14/16   220
# 41        Hero(Mon)          1   10    3    0    5    10   17/19   330
# 42        Hero(Inf)          1    9    3    0    5     5   13/15   145
# 43        Hero(Inf)          1    8    3    0    6     8   14/16   280
# 44        Hero(Inf)          1    5    5    0    4     1   14/16   145
# 45        Hero(Inf)          1    5    5    0    4     1   10/12    85
# 46        Hero(Inf)          1   10    4    0    6     1   17/19   270
#
#                                               Special
# 0                            Shambling; Lifeleech (1)
# 1                            Shambling; Lifeleech (1)
# 2                            Shambling; Lifeleech (1)
# 3                      Bows; Shambling; Lifeleech (1)
# 4                      Bows; Shambling; Lifeleech (1)
# 5                      Bows; Shambling; Lifeleech (1)
# 6                   Phalanx; Shambling; Lifeleech (1)
# 7                   Phalanx; Shambling; Lifeleech (1)
# 8                   Phalanx; Shambling; Lifeleech (1)
# 9                                      Lifeleech (1)
# 10                                     Lifeleech (1)
# 11                                     Lifeleech (1)
# 12               Crushing Strength (2); Lifeleech (2)
# 13               Crushing Strength (2); Lifeleech (2)
# 14   Crushing Strength (1); Lifeleech (2); Thunder...
# 15   Crushing Strength (1); Lifeleech (2); Thunder...
# 16                           Shambling; Lifeleech (2)
# 17                           Shambling; Lifeleech (2)
# 18                           Shambling; Lifeleech (2)
# 19    Shambling; Lifeleech (2); Thunderous Charge (2)
# 20    Shambling; Lifeleech (2); Thunderous Charge (2)
# 21   Crushing Strength (1); Fly; Shambling; Lifele...
# 22   Crushing Strength (1); Fly; Shambling; Lifele...
# 23                           Shambling; Lifeleech (1)
# 24                           Shambling; Lifeleech (1)
# 25                           Shambling; Lifeleech (1)
# 26   Shambling; Lifeleech (1); Crushing Strength (...
# 27   Shambling; Lifeleech (1); Crushing Strength (...
# 28    Shambling; Lifeleech (1); Crushing Strength (2)
# 29    Shambling; Lifeleech (1); Crushing Strength (2)
# 30       Lifeleech (1); Crushing Strength (1); Nimble
# 31       Lifeleech (1); Crushing Strength (1); Nimble
# 32   Lifeleech (1); Crushing Strength (1); Individ...
# 33   Lifeleech (1); Crushing Strength (3); Inspiri...
# 34   Lifeleech (1); Brutal; Crushing Strength (3);...
# 35   Lifeleech (1); Brutal; Crushing Strength (3);...
# 36    Lifeleech (1); Individual; Inspiring; Shambling
# 37   Blast (D6+2); Indirect Fire; Piercing (2); Re...
# 38   Lifeleech (1); Crushing Strength (2); Individ...
# 39   Lifeleech (2); Crushing Strength (2); Fly; In...
# 40   Lifeleech (2); Crushing Strength (2); Individ...
# 41   Breath Attack (10); Crushing Strength (3); Fl...
# 42   Lifeleech (1); Crushing Strength (2); Inspiri...
# 43   Crushing Strength (3); Heal (3); Individual; ...
# 44   Individual; Inspiring; Regeneration (5); Surg...
# 45               Lifeleech (1); Individual; Surge (8)
# 46   Bane-chant (4); Fireball (15); Fly; Heal (6);...
